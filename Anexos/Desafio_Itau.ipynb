# %%
# !git clone https://github.com/beevilela/teste_eng_dados.git
# Out:
# Cloning into 'teste_eng_dados'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 43 (delta 4), reused 41 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 97.41 KiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd /content/teste_eng_dados
# Out:
# /content/teste_eng_dados

# %%
# !git checkout -b solucao-desafio
# Out:
# fatal: A branch named 'solucao-desafio' already exists.

# %%
# !git config user.name "beevilela"
# !git config user.email "vcbettina@gmail.com"

# %%
# !git remote -v
# Out:
# origin	https://github.com/beevilela/teste_eng_dados.git (fetch)
# origin	https://github.com/beevilela/teste_eng_dados.git (push)

# %%
# !git branch
# Out:
#   main
# * solucao-desafio

# %%
# !pwd
# Out:
# /content/teste_eng_dados

# %%
# !ls -la
# Out:
# total 36
# drwxr-xr-x 5 root root 4096 Jul 10 20:28 .
# drwxr-xr-x 1 root root 4096 Jul 10 20:27 ..
# drwxr-xr-x 2 root root 4096 Jul 10 20:27 datasets
# -rw-r--r-- 1 root root  849 Jul 10 20:27 docker-compose.env
# -rw-r--r-- 1 root root 1131 Jul 10 20:27 docker-compose.yml
# drwxr-xr-x 8 root root 4096 Jul 10 20:30 .git
# -rw-r--r-- 1 root root 6555 Jul 10 20:27 README.md
# drwxr-xr-x 4 root root 4096 Jul 10 20:28 teste_eng_dados

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cat README.md

# %% [markdown]
# # Teste Prático para Engenharia de Dados
#
# ## Introdução
#
# O teste é destinado a avaliar as habilidades práticas como Engenheir@ de dados
#
# **Itens do teste:**
# 1. ETL
# 2. Análise dos dados
# 3. Desenho de Arquitetura para ingestão de dados batch
# 4. Implementação de um Data quality
# 5. Desenvolvimento de testes unitários
# 6. Infra as Code (IaC)
#
# ## Fork
# Realize um fork do repositorio e após a conclusão submeta um pull request. Através do PR que as respostas serão revisadas.
#
# ## Sugestão de estrutura dos arquivos de resposta
# ```bash
# ├── 1.ETL/
# │   └── script.py
# ├── 2.AnaliseDados/
# │   └── analise.txt
# ├── 3.DesenhodeArquitetura/
# │   ├── desenho.jpg
# │   └── explicacao.txt
# ├── 4.DataQuality/
# │   └── script_data_quality.py
# ├── 5.TesteUnitario/
# │   ├── unit_test.py
# │   └── resultados.txt
# └── 6.InfraAsCode/
#     └── script.tf
#  ```

# %%
# !mkdir -p \
  1.ETL \
  2.AnaliseDados \
  3.DesenhodeArquitetura \
  4.DataQuality \
  5.TesteUnitario \
  6.InfraAsCode

# %%
# !touch \
  1.ETL/script.py \
  2.AnaliseDados/analise.txt \
  3.DesenhodeArquitetura/explicacao.txt \
  4.DataQuality/script_data_quality.py \
  5.TesteUnitario/unit_test.py \
  5.TesteUnitario/resultados.txt \
  6.InfraAsCode/script.tf

# %%
# !find . -maxdepth 2 -type f | sort
# Out:
# ./1.ETL/script.py
# ./2.AnaliseDados/analise.txt
# ./3.DesenhodeArquitetura/explicacao.txt
# ./4.DataQuality/script_data_quality.py
# ./5.TesteUnitario/resultados.txt
# ./5.TesteUnitario/unit_test.py
# ./6.InfraAsCode/script.tf
# ./datasets/clientes_sinteticos.csv
# ./docker-compose.env
# ./docker-compose.yml
# ./.git/config
# ./.git/description
# ./.git/HEAD
# ./.git/index
# ./.git/packed-refs
# ./README.md

# %%
# !head -n 10 datasets/clientes_sinteticos.csv
# Out:
# cod_cliente,nm_cliente,nm_pais_cliente,nm_cidade_cliente,nm_rua_cliente,num_casa_cliente,telefone_cliente,dt_nascimento_cliente,dt_atualizacao,tp_pessoa,vl_renda
# 980,Krista Rogers,Guadeloupe,Kellyview,Barker Walk,3309,(95)39194-2483,2001-10-29,2024-04-18,PJ,57900.19
# 177,Veronica Russell,Guinea-Bissau,Romanside,Tucker Canyon,268,(42)71167-9960,1991-08-03,2024-10-28,PJ,78775.44
# 267,William Hughes,Mongolia,Taylorview,Daniel Inlet,72089,(70)40026-9752,2006-12-08,2025-01-20,PF,8877.67
# 980,Anita Riggs,Suriname,New Catherinestad,Daniel Plain,54225,001-595-499-9546x079,2002-12-19,2024-04-08,PJ,41326.54
# 530,Alan Humphrey,Belgium,Dianeshire,Wu Inlet,80620,(11)55935-5396,1963-12-18,2024-11-28,PJ,67695.14
# 561,Haley Harris,Swaziland,Michaeltown,Marsh Stravenue,562,(71)90455-9956,1963-02-05,2024-11-04,PJ,48874.57
# 396,Donald Walker,Cayman Islands,New Daisy,Palmer Crescent,25702,723.957.2526x786,1946-03-24,2024-07-18,PJ,20094.37
# ...

# %%
import pandas as pd

df = pd.read_csv("datasets/clientes_sinteticos.csv")

print(df.columns.tolist())
print('\n ')

display(df.head())
print('\n ')

print(df.shape)
print('\n ')

print(df.info())
# Out:
# ['cod_cliente', 'nm_cliente', 'nm_pais_cliente', 'nm_cidade_cliente', 'nm_rua_cliente', 'num_casa_cliente', 'telefone_cliente', 'dt_nascimento_cliente', 'dt_atualizacao', 'tp_pessoa', 'vl_renda']
#    cod_cliente        nm_cliente nm_pais_cliente  nm_cidade_cliente  \
# 0          980     Krista Rogers      Guadeloupe          Kellyview
# 1          177  Veronica Russell   Guinea-Bissau          Romanside
# 2          267    William Hughes        Mongolia         Taylorview
# 3          980       Anita Riggs        Suriname  New Catherinestad
# 4          530     Alan Humphrey         Belgium         Dianeshire
#
#   nm_rua_cliente  num_casa_cliente      telefone_cliente  \
# 0    Barker Walk              3309        (95)39194-2483
# 1  Tucker Canyon               268        (42)71167-9960
# 2   Daniel Inlet             72089        (70)40026-9752
# 3   Daniel Plain             54225  001-595-499-9546x079
# 4       Wu Inlet             80620        (11)55935-5396
#
# ...

# %%
print("Valores nulos por coluna:")
print(df.isnull().sum())

print("\nDuplicados:")
print(df.duplicated().sum())

print("\nResumo estatístico:")
display(df.describe(include="all"))
# Out:
# Valores nulos por coluna:
# cod_cliente              0
# nm_cliente               0
# nm_pais_cliente          0
# nm_cidade_cliente        0
# nm_rua_cliente           0
# num_casa_cliente         0
# telefone_cliente         0
# dt_nascimento_cliente    0
# dt_atualizacao           0
# tp_pessoa                0
# vl_renda                 0
# dtype: int64
#
# Duplicados:
# 0
#
# Resumo estatístico:
#         cod_cliente      nm_cliente nm_pais_cliente nm_cidade_cliente  \
# count    500.000000             500             500               500
# unique          NaN             499             211               487
# top             NaN  Kathleen Singh           Korea      Johnsonmouth
# freq            NaN               2               6                 3
# mean     524.490000             NaN             NaN               NaN
# std      290.488356             NaN             NaN               NaN
# min        2.000000             NaN             NaN               NaN
# ...

# %%
print("Cod Clientes distintos:")
print(df["cod_cliente"].nunique())

print("\nClientes distintos:")
print(df["nm_cliente"].nunique())

print("\nTotal de registros:")
print(len(df))
# Out:
# Cod Clientes distintos:
# 397
#
# Clientes distintos:
# 499
#
# Total de registros:
# 500

# %%
df.groupby("cod_cliente").size().sort_values(ascending=False).head(20)
# Out:
# cod_cliente
# 878    5
# 396    5
# 479    5
# 855    4
# 850    3
# 71     3
# 663    3
# 620    3
# 177    3
# 93     3
# 980    3
# 925    3
# 972    3
# 227    3
# 503    3
# 464    3
# 516    3
# 502    3
# 632    3
# 127    3
# dtype: int64

# %%
df["dt_atualizacao"].head(20)
# Out:
# 0     2024-04-18
# 1     2024-10-28
# 2     2025-01-20
# 3     2024-04-08
# 4     2024-11-28
# 5     2024-11-04
# 6     2024-07-18
# 7     2024-06-14
# 8     2024-06-23
# 9     2024-09-28
# 10    2025-03-23
# 11    2025-03-03
# 12    2024-11-29
# 13    2024-08-05
# 14    2024-07-31
# 15    2024-05-10
# 16    2025-04-02
# 17    2024-09-09
# 18    2024-05-04
# 19    2025-02-23
# Name: dt_atualizacao, dtype: object

# %%
print(df["dt_atualizacao"].min())
print(df["dt_atualizacao"].max())
# Out:
# 2024-04-05
# 2025-04-04

# %%
# !git branch --show-current
# Out:
# solucao-desafio

# %%
# !git remote -v
# Out:
# origin	https://github.com/beevilela/teste_eng_dados.git (fetch)
# origin	https://github.com/beevilela/teste_eng_dados.git (push)

# %%
# !git status
# Out:
# On branch solucao-desafio
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	3.DesenhodeArquitetura/desenho.jpg
# 	3.DesenhodeArquitetura/desenho.png
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
from getpass import getpass

token = getpass("Cole seu Personal Access Token do GitHub: ")
# Out:
# Cole seu Personal Access Token do GitHub: ··········

# %%
# !git pull origin solucao-desafio
# Out:
# From https://github.com/beevilela/teste_eng_dados
#  * branch            solucao-desafio -> FETCH_HEAD
#  * [new branch]      solucao-desafio -> origin/solucao-desafio
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m "Criando a estrutura inicial do desafio"
# Out:
# On branch solucao-desafio
# nothing to commit, working tree clean

# %%
# !git commit -m "Finalizando o item ETL"
# Out:
# On branch solucao-desafio
# nothing to commit, working tree clean

# %%
# !git commit -m "Alterando o script ETL para adicionar as funções de validação de telefone e deduplicação"
# Out:
# [solucao-desafio b3e5e45] Alterando o script ETL para adicionar as funções de validação de telefone e deduplicação
#  1 file changed, 29 insertions(+), 24 deletions(-)

# %%
# !git commit -m "Subindo solução do item 2"
# Out:
# [solucao-desafio 5dbedd5] Subindo solução do item 2
#  1 file changed, 53 insertions(+)

# %%
# !git commit -m "Subindo solução do item 4 e relatórios de teste aplicados na silver e bronze"
# Out:
# [solucao-desafio 693fefc] Subindo solução do item 4 e relatórios de teste aplicados na silver e bronze
#  3 files changed, 557 insertions(+)
#  create mode 100644 4.DataQuality/resultado_bronze.txt
#  create mode 100644 4.DataQuality/resultado_silver.txt

# %%
# !git commit -m "Subindo a solução do item 5 e massa de testes criada para validação"
# Out:
# [solucao-desafio 9510bdf] Subindo a solução do item 5 e massa de testes criada para validação
#  11 files changed, 159 insertions(+)
#  create mode 100644 1.ETL/__pycache__/script.cpython-312.pyc
#  create mode 100644 5.TesteUnitario/dados_teste_clientes.csv
#  create mode 100644 Anexos/bucket-bronze/tabela_cliente_landing/anomesdia=20260711/._SUCCESS.crc
#  create mode 100644 Anexos/bucket-bronze/tabela_cliente_landing/anomesdia=20260711/.part-00000-b651d79c-3413-4e25-a763-e76cd29b78df-c000.snappy.parquet.crc
#  create mode 100644 Anexos/bucket-bronze/tabela_cliente_landing/anomesdia=20260711/_SUCCESS
#  create mode 100644 Anexos/bucket-bronze/tabela_cliente_landing/anomesdia=20260711/part-00000-b651d79c-3413-4e25-a763-e76cd29b78df-c000.snappy.parquet
#  create mode 100644 Anexos/bucket-silver/tb_cliente/anomesdia=20260711/._SUCCESS.crc
#  create mode 100644 Anexos/bucket-silver/tb_cliente/anomesdia=20260711/.part-00000-4d989bec-3d85-4b5d-95bd-4294ff93f8aa-c000.snappy.parquet.crc
# ...

# %%
# !git commit -m "Subindo arquivo de resultados do item 5"
# Out:
# [solucao-desafio 5f3a4c2] Subindo arquivo de resultados do item 5
#  2 files changed, 16 insertions(+), 29 deletions(-)
#  rewrite 5.TesteUnitario/resultados.txt (88%)

# %%
# !git commit -m "Subindo ajustes no script de teste unitário"
# Out:
# [solucao-desafio e8b37bd] Subindo ajustes no script de teste unitário
#  1 file changed, 96 insertions(+), 59 deletions(-)

# %%
# !git commit -m "Subindo o desenho da arquitetura"
# Out:
# [solucao-desafio 865f1b4] Subindo o desenho da arquitetura
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 3.DesenhodeArquitetura/desenho.jpg
#  create mode 100644 3.DesenhodeArquitetura/desenho.png

# %%
# !git commit -m "Finalizando o desafio"
# Out:
# [solucao-desafio cf39d2f] Finalizando o desafio
#  2 files changed, 5 insertions(+), 1 deletion(-)
#  create mode 100644 5.TesteUnitario/resultado_deduplicacao.csv

# %%
import subprocess

repo = f"https://beevilela:{token}@github.com/beevilela/teste_eng_dados.git"

subprocess.run(
    ["git", "push", "-u", repo, "HEAD"],
    check=True
)

# %% [markdown]
# ### 1. ETL
#
# #### Descrição
#
# Utilize o arquivo `clientes_sinteticos.csv`.
#
# Deverá ser gerado um único script que irá escrever em 2 buckets da AWS, um deles Bronze e o outro Silver.
#
# Ambos os arquivos escritos no bucket Bronze e Silver devem estar acessíveis atraves do Glue Data Catalog, o schema de cata tabela pode ser definido por você mas considere que ambas as tabelas já foram criadas(nao a necessidade de criacao). A partição física devera ser a data de processamento e o nome da particao será **anomesdia**, lembre que além da partição física será necessario criar a partição lógica na tabela.
#
# Passos:
# - Especifique um schema para o dataset.
# - Trate os nomes dos clientes para que fique todos com letra maiuscula
# - Renomeie a coluna telefone_cliente para num_telefone_cliente
# - Realize a escrita do dado no bucket s3://bucket-bronze/tabela_cliente_landing
# - Deduplique o dataset mantendo sempre somente a ultima data de atualizacao do cadastro de cada cliente
# - Trate a coluna de telefone de modo a permitir somente valores que sigam o padrao (NN)NNNNN-NNNN os demais devem ficar nulos
# - Realize a escrita do dado no bucket s3://bucket-silver/tb_cliente
# ---

# %%
# imports

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window

spark = SparkSession.builder.appName("ETL").getOrCreate()


# schema

schema = StructType(
    [
        StructField("cod_cliente", IntegerType(), False),
        StructField("nm_cliente", StringType(), False),
        StructField("nm_pais_cliente", StringType(), False),
        StructField("nm_cidade_cliente", StringType(), False),
        StructField("nm_rua_cliente", StringType(), False),
        StructField("num_casa_cliente", IntegerType(), False),
        StructField("telefone_cliente", StringType(), False),
        StructField("dt_nascimento_cliente", DateType(), False),
        StructField("dt_atualizacao", DateType(), False),
        StructField("tp_pessoa", StringType(), False),
        StructField("vl_renda", DecimalType(12, 2), False),
    ]
)


# leitura

df = (
    spark.read
    .option("header", True)
    .schema(schema)
    .csv("datasets/clientes_sinteticos.csv")
)

# %%
from datetime import datetime

data_processamento = datetime.now().strftime("%Y%m%d")

# Bronze

bronze = (df.withColumn("nm_cliente", F.upper(F.trim(F.col("nm_cliente"))))
    .withColumnRenamed("telefone_cliente", "num_telefone_cliente")
    .withColumn("anomesdia", F.lit(data_processamento))
)

# %%
display(bronze.toPandas().head(10))
# Out:
#    cod_cliente        nm_cliente nm_pais_cliente  nm_cidade_cliente  \
# 0          980     KRISTA ROGERS      Guadeloupe          Kellyview
# 1          177  VERONICA RUSSELL   Guinea-Bissau          Romanside
# 2          267    WILLIAM HUGHES        Mongolia         Taylorview
# 3          980       ANITA RIGGS        Suriname  New Catherinestad
# 4          530     ALAN HUMPHREY         Belgium         Dianeshire
# 5          561      HALEY HARRIS       Swaziland        Michaeltown
# 6          396     DONALD WALKER  Cayman Islands          New Daisy
# 7          212       KEVIN SMITH         Bahrain     East Jasontown
# 8          396   JENNIFER MALONE           Korea   Port Victormouth
# 9          763     JUSTIN HUNTER          Rwanda        West Joseph
#
#     nm_rua_cliente  num_casa_cliente  num_telefone_cliente  \
# 0      Barker Walk              3309        (95)39194-2483
# 1    Tucker Canyon               268        (42)71167-9960
# ...

# %%
# !mkdir -p Anexos/bucket-bronze
# !mkdir -p Anexos/bucket-silver

# %%
# !mkdir -p Anexos/csv/bucket-bronze/tabela_cliente_landing
# !mkdir -p Anexos/csv/bucket-silver/tb_cliente

# %%
from datetime import datetime

data_processamento = datetime.now().strftime("%Y%m%d")

# grava Bronze

bronze.write \
    .mode("overwrite") \
    .parquet(
        f"Anexos/bucket-bronze/tabela_cliente_landing/anomesdia={data_processamento}")


bronze.write \
    .mode("overwrite") \
    .option("header", True) \
    .csv(f"Anexos/csv/bucket-bronze/tabela_cliente_landing/anomesdia={data_processamento}")

# %%
PHONE_PATTERN = r"^\(\d{2}\)\d{5}-\d{4}$"

# Silver

window = Window.partitionBy("cod_cliente").orderBy(F.col("dt_atualizacao").desc())

silver = (bronze.withColumn("rn", F.row_number().over(window))
    .filter(F.col("rn") == 1)
    .drop("rn")
)

silver = (silver.withColumn("num_telefone_cliente",
        F.when(F.col("num_telefone_cliente").rlike(PHONE_PATTERN),
            F.col("num_telefone_cliente"))
        .otherwise(F.lit(None)))
)

# %%
display(silver.toPandas().head(10))
# Out:
#    cod_cliente         nm_cliente           nm_pais_cliente  \
# 0            2     APRIL SANDOVAL  United States of America
# 1            5         APRIL SHAW                 Sri Lanka
# 2            6    DANIEL PETERSON                  Slovenia
# 3            7      MICHAEL WEISS             French Guiana
# 4            8    KATHLEEN WILSON                   Tokelau
# 5           16  JEANETTE PETERSON               Timor-Leste
# 6           17         JILL AVERY                Micronesia
# 7           18    MICHELLE HOWARD            Western Sahara
# 8           19       GEORGE LOPEZ                  Tanzania
# 9           25      JUSTIN CHAVEZ                    Poland
#
#    nm_cidade_cliente   nm_rua_cliente  num_casa_cliente num_telefone_cliente  \
# 0         Dianaburgh      Brian Inlet              2721       (82)23630-7260
# 1         Lindaville       Brad Vista             13916       (83)25671-9895
# ...

# %%
# grava Silver

silver.write \
    .mode("overwrite") \
    .parquet(
        f"Anexos/bucket-silver/tb_cliente/anomesdia={data_processamento}")


silver.write \
    .mode("overwrite") \
    .option("header", True) \
    .csv(f"Anexos/csv/bucket-silver/tb_cliente/anomesdia={data_processamento}")

# %%
# %%writefile 1.ETL/script.py

import boto3

from datetime import datetime

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import (
    StructType,
    StructField,
    IntegerType,
    StringType,
    DateType,
    DecimalType,
)
from pyspark.sql.window import Window



# 1. CONFIGURAÇÕES


SOURCE_PATH = "datasets/clientes_sinteticos.csv"

BRONZE_PATH = "s3://bucket-bronze/tabela_cliente_landing"
SILVER_PATH = "s3://bucket-silver/tb_cliente"

GLUE_DATABASE = "clientes_database"
BRONZE_TABLE = "tabela_cliente_landing"
SILVER_TABLE = "tb_cliente"

PROCESSING_DATE = datetime.now().strftime("%Y%m%d")

PHONE_PATTERN = r"^\(\d{2}\)\d{5}-\d{4}$"



# 2. CRIAÇÃO DA SESSÃO SPARK


spark = (
    SparkSession.builder
    .appName("etl_clientes")
    .config("spark.sql.adaptive.enabled", "true")
    .config(
        "spark.sql.adaptive.coalescePartitions.enabled",
        "true"
    )
    .config(
        "spark.sql.adaptive.skewJoin.enabled",
        "true"
    )
    .getOrCreate()
)



# 3. DEFINIÇÃO DO SCHEMA


schema = StructType(
    [
        StructField("cod_cliente", IntegerType(), False),
        StructField("nm_cliente", StringType(), False),
        StructField("nm_pais_cliente", StringType(), False),
        StructField("nm_cidade_cliente", StringType(), False),
        StructField("nm_rua_cliente", StringType(), False),
        StructField("num_casa_cliente", IntegerType(), False),
        StructField("telefone_cliente", StringType(), False),
        StructField("dt_nascimento_cliente", DateType(), False),
        StructField("dt_atualizacao", DateType(), False),
        StructField("tp_pessoa", StringType(), False),
        StructField("vl_renda", DecimalType(12, 2), False),
    ]
)



# 4. LEITURA DO CSV


df_origem = (
    spark.read
    .option("header", "true")
    .option("dateFormat", "yyyy-MM-dd")
    .schema(schema)
    .csv(SOURCE_PATH)
)



# 5. TRANSFORMAÇÕES DA CAMADA BRONZE


df_bronze = (
    df_origem
    .withColumn(
        "nm_cliente",
        F.upper(F.trim(F.col("nm_cliente"))),
    )
    .withColumnRenamed(
        "telefone_cliente",
        "num_telefone_cliente",
    )
)



# 6. ESCRITA DA BRONZE NO S3


bronze_partition_path = (
    f"{BRONZE_PATH}/anomesdia={PROCESSING_DATE}"
)

(
    df_bronze.write
    .mode("overwrite")
    .format("parquet")
    .save(bronze_partition_path)
)



# 7. REGISTRO DA PARTIÇÃO BRONZE NO GLUE


glue_client = boto3.client("glue")

bronze_table_response = glue_client.get_table(
    DatabaseName=GLUE_DATABASE,
    Name=BRONZE_TABLE,
)

bronze_storage = bronze_table_response["Table"]["StorageDescriptor"]

bronze_partition = {
    "Values": [PROCESSING_DATE],
    "StorageDescriptor": {
        "Columns": bronze_storage["Columns"],
        "Location": bronze_partition_path,
        "InputFormat": bronze_storage.get("InputFormat"),
        "OutputFormat": bronze_storage.get("OutputFormat"),
        "SerdeInfo": bronze_storage.get("SerdeInfo"),
        "Compressed": bronze_storage.get("Compressed", False),
        "Parameters": bronze_storage.get("Parameters", {}),
    },
}

bronze_response = glue_client.batch_create_partition(
    DatabaseName=GLUE_DATABASE,
    TableName=BRONZE_TABLE,
    PartitionInputList=[bronze_partition],
)

for error in bronze_response.get("Errors", []):
    error_code = error.get("ErrorDetail", {}).get("ErrorCode")

    if error_code != "AlreadyExistsException":
        raise RuntimeError(
            f"Erro ao registrar a partição Bronze: {error}"
        )



# 8. DEDUPLICAÇÃO PARA A CAMADA SILVER


def deduplicar_clientes(dataframe, numero_particoes=None):
    if numero_particoes:
        dataframe = dataframe.repartition(
            numero_particoes,
            "cod_cliente"
        )

    janela_cliente = (
        Window
        .partitionBy("cod_cliente")
        .orderBy(F.col("dt_atualizacao").desc())
    )

    return (
        dataframe
        .withColumn(
            "ordem_atualizacao",
            F.row_number().over(janela_cliente)
        )
        .filter(F.col("ordem_atualizacao") == 1)
        .drop("ordem_atualizacao")
    )


df_silver = deduplicar_clientes(df_bronze, numero_particoes=40)



# 9. VALIDAÇÃO DO TELEFONE


def validar_telefone(dataframe):
    return (
        dataframe.withColumn(
            "num_telefone_cliente",
            F.when(
                F.col("num_telefone_cliente").rlike(PHONE_PATTERN),
                F.col("num_telefone_cliente")
            ).otherwise(F.lit(None))
        )
    )


df_silver = validar_telefone(df_silver)



# 10. ESCRITA DA SILVER NO S3


silver_partition_path = (
    f"{SILVER_PATH}/anomesdia={PROCESSING_DATE}"
)

(
    df_silver.write
    .mode("overwrite")
    .format("parquet")
    .save(silver_partition_path)
)



# 11. REGISTRO DA PARTIÇÃO SILVER NO GLUE


silver_table_response = glue_client.get_table(
    DatabaseName=GLUE_DATABASE,
    Name=SILVER_TABLE,
)

silver_storage = silver_table_response["Table"]["StorageDescriptor"]

silver_partition = {
    "Values": [PROCESSING_DATE],
    "StorageDescriptor": {
        "Columns": silver_storage["Columns"],
        "Location": silver_partition_path,
        "InputFormat": silver_storage.get("InputFormat"),
        "OutputFormat": silver_storage.get("OutputFormat"),
        "SerdeInfo": silver_storage.get("SerdeInfo"),
        "Compressed": silver_storage.get("Compressed", False),
        "Parameters": silver_storage.get("Parameters", {}),
    },
}

silver_response = glue_client.batch_create_partition(
    DatabaseName=GLUE_DATABASE,
    TableName=SILVER_TABLE,
    PartitionInputList=[silver_partition],
)

for error in silver_response.get("Errors", []):
    error_code = error.get("ErrorDetail", {}).get("ErrorCode")

    if error_code != "AlreadyExistsException":
        raise RuntimeError(
            f"Erro ao registrar a partição Silver: {error}"
        )



# 12. FINALIZAÇÃO


print("ETL concluído com sucesso.")
print(f"Partição processada: anomesdia={PROCESSING_DATE}")

spark.stop()
# Out:
# Overwriting 1.ETL/script.py

# %%
# !git clone https://github.com/beevilela/teste_eng_dados.git

# %cd teste_eng_dados

# !git fetch --all

#!git switch solucao-desafio
# Out:
# Cloning into 'teste_eng_dados'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 152 (delta 42), reused 81 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 123.59 KiB | 1.51 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/teste_eng_dados
# Fetching origin

# %%
# !git checkout -b solucao-desafio origin/solucao-desafio
# Out:
# Branch 'solucao-desafio' set up to track remote branch 'solucao-desafio' from 'origin'.
# Switched to a new branch 'solucao-desafio'

# %%
# !git status
# Out:
# On branch solucao-desafio
# Your branch is up to date with 'origin/solucao-desafio'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### 2. Análise dos dados
#
# Utilize o arquivo `clientes_sinteticos.csv`.
# #### Descrição
#
# - Identifique os 5 clientes que mais sofreram atualizações na base.
# - Calcule a média de idade dos clientes.
# ---

# %%
import pandas as pd

df = pd.read_csv("datasets/clientes_sinteticos.csv")

top5 = (
    df.groupby(["cod_cliente"])
      .size()
      .reset_index(name="qtd_atualizacoes")
      .sort_values(
          by="qtd_atualizacoes",
          ascending=False
      )
      .head(5)
)

print(top5)
# Out:
#      cod_cliente  qtd_atualizacoes
# 341          878                 5
# 144          396                 5
# 180          479                 5
# 334          855                 4
# 332          850                 3

# %%
from datetime import datetime

df["dt_nascimento_cliente"] = pd.to_datetime(
    df["dt_nascimento_cliente"]
)

hoje = pd.Timestamp.today()

df["idade"] = (
    (hoje - df["dt_nascimento_cliente"]).dt.days
    / 365.25
)

media_idade = df["idade"].mean()

print(media_idade)
# Out:
# 51.166313483915125

# %%
relatorio = f"""
ANÁLISE DOS DADOS
============================================================

Objetivo

Realizar as análises solicitadas utilizando o arquivo
clientes_sinteticos.csv.

============================================================

1. Clientes com maior número de atualizações

Critério

Foi utilizado o campo cod_cliente como identificador único do cliente,
uma vez que ao longo do tempo, diferentes nm_cliente assumem o mesmo
cod_cliente no cadastro.

Resultado

Foram identificados os cinco códigos de cliente com maior número de
atualizações no histórico cadastral.

{top5.to_markdown(index=False)}

============================================================

2. Média de idade dos clientes

Resultado

{media_idade:.2f} anos

============================================================

Observações

• A análise foi realizada diretamente sobre o CSV conforme
  especificado no enunciado.

• Em ambiente produtivo, a contagem de atualizações seria
  realizada sobre a camada Bronze.

• Em uma análise realizada sob o nome dos clientes, curiosamente
  foi encontrado um homônimo: Kathleen Singh.

"""

# %%
with open(
    "2.AnaliseDados/analise.txt",
    "w",
    encoding="utf-8"
) as arquivo:

    arquivo.write(relatorio)

# %% [markdown]
# ### 3. Desenho de Arquitetura
#
# #### Descrição
#
# Proponha uma arquitetura na AWS para coletar dados de cadastros de clientes em um banco MySQL. Esses dados devem ser persistidos em um datalake que usa a arquitetura medalhão:
#
# - Desenhe um sistema para coletar dados do banco MySQL realizando CDC.
# - O processamento e escrita deve ser projetado para os 3 niveis do lake (bronze, silver e gold)
# - Além do armazenamento do dado será necessaria uma governança de acesso a nível de usuário
# ---

# %%
# !apt-get update -qq
# !apt-get install graphviz -y -qq
# !pip install graphviz -q
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
from graphviz import Digraph
from pathlib import Path

pasta_saida = Path("3.DesenhodeArquitetura")

diagrama = Digraph(
    name="arquitetura_aws",
    format="png"
)

# Direção do fluxo: esquerda para direita
diagrama.attr(
    rankdir="LR",
    bgcolor="white",
    label="Arquitetura AWS — CDC e Data Lake Medalhão",
    labelloc="t",
    fontsize="20",
    fontname="Arial"
)

# Aparência padrão dos blocos
diagrama.attr(
    "node",
    shape="box",
    style="rounded,filled",
    fontname="Arial",
    fontsize="11",
    margin="0.15"
)

diagrama.attr(
    "edge",
    fontname="Arial",
    fontsize="9"
)

# Origem e ingestão
diagrama.node(
    "mysql",
    "Banco MySQL\nCadastro de clientes",
    fillcolor="#DCEEFF"
)

diagrama.node(
    "dms",
    "AWS DMS\nFull Load + CDC",
    fillcolor="#E8DEFF"
)

# Camadas do Data Lake
diagrama.node(
    "bronze",
    "Amazon S3 — Bronze\nDados brutos e histórico",
    fillcolor="#F3C98B"
)

diagrama.node(
    "silver",
    "Amazon S3 — Silver\nDados tratados e deduplicados",
    fillcolor="#D9D9D9"
)

diagrama.node(
    "gold",
    "Amazon S3 — Gold\nDados agregados para negócio",
    fillcolor="#FFE082"
)

# Consumo
diagrama.node(
    "consumo",
    "Athena / Redshift\nQuickSight / Aplicações",
    fillcolor="#E8DEFF"
)

# Fluxo principal
diagrama.edge(
    "mysql",
    "dms",
    label="binlog / CDC"
)

diagrama.edge(
    "dms",
    "bronze",
    label="inserts, updates e deletes"
)

diagrama.edge(
    "bronze",
    "silver",
    label="AWS Glue ETL"
)

diagrama.edge(
    "silver",
    "gold",
    label="AWS Glue ETL"
)

diagrama.edge(
    "gold",
    "consumo",
    label="consulta e análise"
)

# Catálogo e governança
diagrama.node(
    "catalogo",
    "AWS Glue Data Catalog\nSchemas, tabelas e partições",
    fillcolor="#E2F0D9"
)

diagrama.node(
    "governanca",
    "AWS Lake Formation + IAM\nAcesso por usuário, tabela e coluna",
    fillcolor="#E2F0D9"
)

diagrama.node(
    "monitoramento",
    "Amazon CloudWatch\nLogs, métricas e alertas",
    fillcolor="#F7D6E6"
)

# Linhas tracejadas representam controles e metadados
diagrama.edge(
    "catalogo",
    "bronze",
    style="dashed",
    arrowhead="none"
)

diagrama.edge(
    "catalogo",
    "silver",
    style="dashed",
    arrowhead="none"
)

diagrama.edge(
    "catalogo",
    "gold",
    style="dashed",
    arrowhead="none"
)

diagrama.edge(
    "governanca",
    "catalogo",
    label="permissões",
    style="dashed"
)

diagrama.edge(
    "monitoramento",
    "dms",
    style="dashed",
    arrowhead="none"
)

diagrama.edge(
    "monitoramento",
    "silver",
    style="dashed",
    arrowhead="none"
)

# Gera:
# 3.DesenhodeArquitetura/desenho.png
caminho_gerado = diagrama.render(
    filename=str(pasta_saida / "desenho"),
    cleanup=True
)

print(f"Diagrama criado em: {caminho_gerado}")

diagrama
# Out:
# Diagrama criado em: 3.DesenhodeArquitetura/desenho.png

# %%
from PIL import Image

imagem = Image.open("3.DesenhodeArquitetura/desenho.png").convert("RGB")

imagem.save("3.DesenhodeArquitetura/desenho.jpg", quality=95)

print("Arquivo desenho.jpg criado.")
# Out:
# Arquivo desenho.jpg criado.

# %% [markdown]
# ### 4. Data Quality
#
# #### Descrição
#
# A qualidade dos dados é fundamental para garantir que as análises e os insights derivados sejam confiáveis.
#
# - Considere que voce está implementando o processo de Qualidade dos dados na camada Silver do lake na tabela de clientes que você ja preparou anteriormente.
# - Crie um script de modo a validar as dimensões de qualidade que você julgue necessario para esse dataset.
# ---

# %%
# %%writefile 4.DataQuality/script_data_quality.py

import argparse
from datetime import datetime
from pathlib import Path

from pyspark.sql import DataFrame, SparkSession
from pyspark.sql import functions as F


"""
Regras de qualidade:

· Completude: campos obrigatórios não podem ser nulos.

· Unicidade: deve existir apenas um registro por cod_cliente.

· Validade: telefone, tipo de pessoa, datas, renda e idade devem respeitar as
regras.

· Consistência: nome deve estar em maiúsculas e datas precisam fazer sentido.

· Volume: a tabela não pode estar vazia.

· Schema: as colunas esperadas devem existir.

"""



# COnfigurações


CAMINHO_SILVER = (
    "Anexos/bucket-silver/tb_cliente/anomesdia=20260710"
)

CAMINHO_BRONZE = (
    "Anexos/bucket-bronze/tabela_cliente_landing/anomesdia=20260710"
)

CAMINHO_RELATORIO_SILVER = (
    "4.DataQuality/resultado_silver.txt"
)

CAMINHO_RELATORIO_BRONZE = (
    "4.DataQuality/resultado_bronze.txt"
)

PADRAO_TELEFONE = r"^\(\d{2}\)\d{5}-\d{4}$"

COLUNAS_OBRIGATORIAS = [
    "cod_cliente",
    "nm_cliente",
    "nm_pais_cliente",
    "nm_cidade_cliente",
    "nm_rua_cliente",
    "num_casa_cliente",
    "dt_nascimento_cliente",
    "dt_atualizacao",
    "tp_pessoa",
    "vl_renda",
]

COLUNAS_ESPERADAS = [
    "cod_cliente",
    "nm_cliente",
    "nm_pais_cliente",
    "nm_cidade_cliente",
    "nm_rua_cliente",
    "num_casa_cliente",
    "num_telefone_cliente",
    "dt_nascimento_cliente",
    "dt_atualizacao",
    "tp_pessoa",
    "vl_renda",
]



# Função de Data Quality


def executar_data_quality(dataframe, nome_camada, caminho_relatorio):

    resultados = []


# 1. Completude
# Campos obrigatórios não podem ser nulos


    for coluna in COLUNAS_OBRIGATORIAS:

        quantidade_nulos = (
            dataframe
            .filter(F.col(coluna).isNull())
            .count()
        )

        status = (
            "APROVADO"
            if quantidade_nulos == 0
            else "REPROVADO"
        )

        resultados.append(
            f"Completude - {coluna}: "
            f"{status} | Nulos encontrados: {quantidade_nulos}"
        )



# 2. Unicidade
# Deve existir apenas um registro por cod_cliente


    clientes_duplicados = (
        dataframe
        .groupBy("cod_cliente")
        .count()
        .filter(F.col("count") > 1)
        .count()
    )

    status_unicidade = (
        "APROVADO"
        if clientes_duplicados == 0
        else "REPROVADO"
    )

    resultados.append(
        "Unicidade - cod_cliente: "
        f"{status_unicidade} | "
        f"Códigos duplicados encontrados: {clientes_duplicados}"
    )



# 3. Validade
# Telefone, tipo de pessoa, datas, renda e idade

# 3.1 Telefone:
# Pode ser nulo, mas, quando preenchido, deve seguir o padrão.

    telefones_invalidos = (
        dataframe
        .filter(
            F.col("num_telefone_cliente").isNotNull()
            & ~F.col("num_telefone_cliente").rlike(
                PADRAO_TELEFONE
            )
        )
        .count()
    )

    status_telefone = (
        "APROVADO"
        if telefones_invalidos == 0
        else "REPROVADO"
    )

    resultados.append(
        "Validade - telefone: "
        f"{status_telefone} | "
        f"Telefones inválidos encontrados: {telefones_invalidos}"
    )


# 3.2 Tipo de pessoa:
# Somente PF ou PJ são aceitos.

    tipos_pessoa_invalidos = (
        dataframe
        .filter(
            ~F.col("tp_pessoa").isin("PF", "PJ")
        )
        .count()
    )

    status_tipo_pessoa = (
        "APROVADO"
        if tipos_pessoa_invalidos == 0
        else "REPROVADO"
    )

    resultados.append(
        "Validade - tipo de pessoa: "
        f"{status_tipo_pessoa} | "
        f"Valores inválidos encontrados: {tipos_pessoa_invalidos}"
    )


# 3.3 Renda:
# Não pode ser negativa.

    rendas_invalidas = (
        dataframe
        .filter(F.col("vl_renda") < 0)
        .count()
    )

    status_renda = (
        "APROVADO"
        if rendas_invalidas == 0
        else "REPROVADO"
    )

    resultados.append(
        "Validade - renda: "
        f"{status_renda} | "
        f"Rendas negativas encontradas: {rendas_invalidas}"
    )


# 3.4 Data de nascimento:
# Não pode ser uma data futura.

    nascimentos_futuros = (
        dataframe
        .filter(
            F.col("dt_nascimento_cliente")
            > F.current_date()
        )
        .count()
    )

    status_nascimento = (
        "APROVADO"
        if nascimentos_futuros == 0
        else "REPROVADO"
    )

    resultados.append(
        "Validade - data de nascimento: "
        f"{status_nascimento} | "
        f"Datas futuras encontradas: {nascimentos_futuros}"
    )


# 3.5 Idade:
# Não pode ser negativa.

    df_com_idade = dataframe.withColumn(
        "idade",
        F.floor(
            F.months_between(
                F.current_date(),
                F.col("dt_nascimento_cliente"),
            ) / 12
        ),
    )

    idades_invalidas = (
        df_com_idade
        .filter(
            (F.col("idade") < 0)
        )
        .count()
    )

    status_idade = (
        "APROVADO"
        if idades_invalidas == 0
        else "REPROVADO"
    )

    resultados.append(
        "Validade - idade: "
        f"{status_idade} | "
        f"Idades fora da faixa de 0 a 120 anos: "
        f"{idades_invalidas}"
    )


# 4. Consistência
# Nome em maiúsculas e datas de atualização posteriores ao nascimento

# 4.1 Nome em letras maiúsculas

    nomes_fora_padrao = (
        dataframe
        .filter(
            F.col("nm_cliente")
            != F.upper(F.trim(F.col("nm_cliente")))
        )
        .count()
    )

    status_nome = (
        "APROVADO"
        if nomes_fora_padrao == 0
        else "REPROVADO"
    )

    resultados.append(
        "Consistência - nome em maiúsculas: "
        f"{status_nome} | "
        f"Nomes fora do padrão: {nomes_fora_padrao}"
    )


# 4.2 Data de atualização:
# Não deve ser anterior à data de nascimento.

    datas_inconsistentes = (
        dataframe
        .filter(
            F.col("dt_atualizacao")
            < F.col("dt_nascimento_cliente")
        )
        .count()
    )

    status_datas = (
        "APROVADO"
        if datas_inconsistentes == 0
        else "REPROVADO"
    )

    resultados.append(
        "Consistência - datas: "
        f"{status_datas} | "
        f"Atualizações anteriores ao nascimento: "
        f"{datas_inconsistentes}"
    )



# 5. Volume
# O parquet a ser ingestado não pode estar vazio


    total_registros = dataframe.count()

    status_volume = (
        "APROVADO"
        if total_registros > 0
        else "REPROVADO"
    )

    resultados.append(
        "Volume - tabela não vazia: "
        f"{status_volume} | "
        f"Total de registros: {total_registros}"
    )



# 6. Schema
# Valida se as colunas obrigatórias existem


    colunas_ausentes = []

    for coluna in COLUNAS_ESPERADAS:
        if coluna not in dataframe.columns:
            colunas_ausentes.append(coluna)

    status_schema = (
        "APROVADO"
        if len(colunas_ausentes) == 0
        else "REPROVADO"
    )

    if len(colunas_ausentes) == 0:
        detalhe_schema = "Nenhuma coluna ausente"
    else:
        detalhe_schema = ", ".join(colunas_ausentes)

    resultados.append(
        "Schema - colunas esperadas: "
        f"{status_schema} | "
        f"{detalhe_schema}"
    )



# Gerando os relatórios


    quantidade_reprovacoes = sum(
        1
        for resultado in resultados
        if "REPROVADO" in resultado
    )

    status_geral = (
        "APROVADO"
        if quantidade_reprovacoes == 0
        else "REPROVADO"
    )

    relatorio = f"""
RELATÓRIO DE QUALIDADE DE DADOS - CAMADA {nome_camada.upper()}
======================================================================

As validações foram executadas na seguinte ordem:

1. Completude
2. Unicidade
3. Validade
4. Consistência
5. Volume
6. Schema

RESULTADOS
======================================================================

"""

    relatorio += "\n".join(resultados)

    relatorio += f"""

======================================================================

STATUS GERAL: {status_geral}

Quantidade de regras reprovadas: {quantidade_reprovacoes}

"""

    with open(
        caminho_relatorio,
        "w",
        encoding="utf-8",
    ) as arquivo:
        arquivo.write(relatorio)

    print(relatorio)



# Iniciando validação


spark = (
    SparkSession.builder
    .appName("data_quality_clientes")
    .getOrCreate()
)


df_bronze = spark.read.parquet(CAMINHO_BRONZE)

df_silver = spark.read.parquet(CAMINHO_SILVER)



# Execução do Data Quality da Bronze


executar_data_quality(
    dataframe=df_bronze,
    nome_camada="Bronze",
    caminho_relatorio=CAMINHO_RELATORIO_BRONZE,
)



# Execução do Data Quality da Silver


executar_data_quality(
    dataframe=df_silver,
    nome_camada="Silver",
    caminho_relatorio=CAMINHO_RELATORIO_SILVER,
)


spark.stop()
# Out:
# Overwriting 4.DataQuality/script_data_quality.py

# %% [markdown]
# ### 5. Teste Unitário
#
# #### Descrição
#
# Os testes unitários são fundamentais para garantir a robustez e confiabilidade do código, permitindo identificar e corrigir bugs e erros antes que eles atinjam o ambiente de produção. Para este desafio:
#
# - Escolha uma das funções ou classes que você implementou nas etapas anteriores deste teste.
# - Escreva testes unitários para esta função ou classe. Os testes devem cobrir:
#   - Casos padrão ou "happy path".
#   - Casos de borda ou extremos.
#   - Situações de erro ou exceção.
# - Utilize uma biblioteca de testes de sua escolha (como `pytest`, `unittest`, etc.).
# ---

# %%
# %%writefile 5.TesteUnitario/dados_teste_clientes.csv
# cod_cliente,nm_cliente,dt_atualizacao
# 1,CLIENTE ANTIGO,2024-01-10
# 1,CLIENTE INTERMEDIARIO,2024-06-15
# 1,CLIENTE MAIS RECENTE,2025-02-20
# 2,CLIENTE UNICO,2024-08-01
# 3,PRIMEIRA VERSAO,2024-03-10
# 3,SEGUNDA VERSAO,2024-12-25
# Out:
# Writing 5.TesteUnitario/dados_teste_clientes.csv

# %%
import ast
import unittest
from pathlib import Path

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.utils import AnalysisException


CAMINHO_SCRIPT_ETL = Path("1.ETL/script.py")
CAMINHO_DADOS_TESTE = Path("5.TesteUnitario/dados_teste_clientes.csv")


def carregar_funcao_do_script(
    caminho_script: Path,
    nome_funcao: str,
):
    """
    Carrega somente uma função específica do script.

    O restante do arquivo não é executado. Dessa forma,
    as conexões com boto3, Glue e S3 não são acionadas.
    """
    codigo_fonte = caminho_script.read_text(
        encoding="utf-8"
    )

    arvore_sintatica = ast.parse(codigo_fonte)

    funcao_encontrada = None

    for item in arvore_sintatica.body:
        if (
            isinstance(item, ast.FunctionDef)
            and item.name == nome_funcao
        ):
            funcao_encontrada = item
            break

    if funcao_encontrada is None:
        raise ImportError(
            f"A função '{nome_funcao}' não foi encontrada "
            f"em {caminho_script}."
        )

    modulo_funcao = ast.Module(
        body=[funcao_encontrada],
        type_ignores=[],
    )

    ast.fix_missing_locations(modulo_funcao)

    ambiente_execucao = {
        "F": F,
        "Window": Window,
    }

    codigo_compilado = compile(
        modulo_funcao,
        filename=str(caminho_script),
        mode="exec",
    )

    exec(
        codigo_compilado,
        ambiente_execucao,
    )

    return ambiente_execucao[nome_funcao]


deduplicar_clientes = carregar_funcao_do_script(
    CAMINHO_SCRIPT_ETL,
    "deduplicar_clientes",
)

class TestDeduplicarClientes(unittest.TestCase):

    @classmethod
    def setUpClass(cls):
        cls.spark = (
            SparkSession.builder
            .master("local[1]")
            .appName("teste_deduplicacao_clientes")
            .getOrCreate()
        )

        cls.spark.sparkContext.setLogLevel("ERROR")

    @classmethod
    def tearDownClass(cls):
        cls.spark.stop()

    def carregar_base_teste(self):
        """
        Carrega a massa de dados criada para os testes.
        """
        return (
            self.spark.read
            .option("header", "true")
            .option("inferSchema", "true")
            .option("dateFormat", "yyyy-MM-dd")
            .csv(str(CAMINHO_DADOS_TESTE))
        )

    def test_happy_path_mantem_ultima_atualizacao(self):
        """
        Happy path:
        mantém somente o cadastro mais recente
        de cada cliente.
        """
        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        registros = {
            linha["cod_cliente"]: linha["nm_cliente"]
            for linha in resultado.collect()
        }

        self.assertEqual(resultado.count(), 3)

        self.assertEqual(
            registros[1],
            "CLIENTE MAIS RECENTE",
        )

        self.assertEqual(
            registros[3],
            "SEGUNDA VERSAO",
        )

    def test_caso_borda_cliente_com_um_registro(self):
        """
        Caso de borda:
        cliente com apenas um registro deve ser mantido.
        """
        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        cliente_unico = (
            resultado
            .filter(F.col("cod_cliente") == 2)
            .collect()
        )

        self.assertEqual(len(cliente_unico), 1)

        self.assertEqual(
            cliente_unico[0]["nm_cliente"],
            "CLIENTE UNICO",
        )

    def test_resultado_sem_codigos_duplicados(self):
        """
        Caso extremo:
        nenhum código de cliente deve permanecer duplicado.
        """
        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        total_registros = resultado.count()

        total_codigos_distintos = (
            resultado
            .select("cod_cliente")
            .distinct()
            .count()
        )

        self.assertEqual(
            total_registros,
            total_codigos_distintos,
        )

    def test_erro_sem_coluna_dt_atualizacao(self):
        """
        Situação de erro:
        a função deve falhar quando dt_atualizacao
        não estiver presente.
        """
        dataframe = self.spark.createDataFrame(
            [
                (1, "CLIENTE SEM DATA"),
            ],
            [
                "cod_cliente",
                "nm_cliente",
            ],
        )

        with self.assertRaises(AnalysisException):
            deduplicar_clientes(dataframe).collect()


from io import StringIO
import sys

# Captura a saída do unittest
saida = StringIO()

runner = unittest.TextTestRunner(
    stream=saida,
    verbosity=2
)

suite = unittest.TestLoader().loadTestsFromTestCase(
    TestDeduplicarClientes
)

resultado = runner.run(suite)

# Imprime no notebook
print(saida.getvalue())

# Salva exatamente a mesma saída no arquivo
with open("5.TesteUnitario/resultados.txt","w",encoding="utf-8") as arquivo:
    arquivo.write(saida.getvalue())
# Out:
# {"ts": "2026-07-12 14:38:47.929", "level": "ERROR", "logger": "DataFrameQueryContextLogger", "msg": "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `dt_atualizacao` cannot be resolved. Did you mean one of the following? [`cod_cliente`, `nm_cliente`]. SQLSTATE: 42703", "context": {"file": "line 179 in cell [30]", "line": "", "fragment": "col", "errorClass": "UNRESOLVED_COLUMN.WITH_SUGGESTION"}, "exception": {"class": "Py4JJavaError", "msg": "An error occurred while calling o770.withColumn.\n: org.apache.spark.sql.AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `dt_atualizacao` cannot be resolved. Did you mean one of the following? [`cod_cliente`, `nm_cliente`]. SQLSTATE: 42703;\n'Project [cod_cliente#442L, nm_cliente#443, row_number() windowspecdefinition(cod_cliente#442L, 'dt_atualizacao DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS ordem_atu
# ...

# %%
from pyspark.sql import SparkSession

# Cria uma SparkSession
spark = (
    SparkSession.builder
    .master("local[1]")
    .appName("evidencia_deduplicacao")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("ERROR")

# Carrega a massa de teste
dataframe_teste = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .option("dateFormat", "yyyy-MM-dd")
    .csv(str(CAMINHO_DADOS_TESTE))
)

# Executa a função
resultado = deduplicar_clientes(dataframe_teste)

# Mostra o resultado
resultado.show()

# Salva em CSV
resultado.toPandas().to_csv(
    "5.TesteUnitario/resultado_deduplicacao.csv",
    index=False,
    encoding="utf-8"
)

print("Resultado salvo com sucesso!")
# Out:
# +-----------+--------------------+--------------+
# |cod_cliente|          nm_cliente|dt_atualizacao|
# +-----------+--------------------+--------------+
# |          1|CLIENTE MAIS RECENTE|    2025-02-20|
# |          2|       CLIENTE UNICO|    2024-08-01|
# |          3|      SEGUNDA VERSAO|    2024-12-25|
# +-----------+--------------------+--------------+
#
# Resultado salvo com sucesso!

# %%
# !cat 5.TesteUnitario/resultados.txt
# Out:
# test_caso_borda_cliente_com_um_registro (__main__.TestDeduplicarClientes.test_caso_borda_cliente_com_um_registro)
# Caso de borda: ... ok
# test_erro_sem_coluna_dt_atualizacao (__main__.TestDeduplicarClientes.test_erro_sem_coluna_dt_atualizacao)
# Situação de erro: ... ok
# test_happy_path_mantem_ultima_atualizacao (__main__.TestDeduplicarClientes.test_happy_path_mantem_ultima_atualizacao)
# Happy path: ... ok
# test_resultado_sem_codigos_duplicados (__main__.TestDeduplicarClientes.test_resultado_sem_codigos_duplicados)
# Caso extremo: ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 26.901s
#
# OK

# %%
# %%writefile 5.TesteUnitario/unit_test.py

import importlib.util
import unittest
from datetime import date
from pathlib import Path

from pyspark.sql import SparkSession
from pyspark.sql.utils import AnalysisException



# Importação do script ETL e massa de dados


CAMINHO_SCRIPT_ETL = Path("1.ETL/script.py")

CAMINHO_DADOS_TESTE = Path("5.TesteUnitario/dados_teste_clientes.csv")


spec = importlib.util.spec_from_file_location(
    "script_etl",
    CAMINHO_SCRIPT_ETL,
)

script_etl = importlib.util.module_from_spec(spec)
spec.loader.exec_module(script_etl)

deduplicar_clientes = script_etl.deduplicar_clientes



# Testes unitários


class TestDeduplicarClientes(unittest.TestCase):

    @classmethod
    def setUpClass(cls):
        cls.spark = (
            SparkSession.builder
            .master("local[1]")
            .appName("teste_deduplicar_clientes")
            .getOrCreate()
        )

        cls.spark.sparkContext.setLogLevel("ERROR")

    @classmethod
    def tearDownClass(cls):
        cls.spark.stop()



    """
    Lê a massa de dados criada especificamente para os testes unitários.
    """

    def carregar_base_teste(self):
        return (
            self.spark.read
            .option("header", "true")
            .option("inferSchema", "true")
            .option("dateFormat", "yyyy-MM-dd")
            .csv(str(CAMINHO_DADOS_TESTE))
        )



    """
    Happy path: apenas a versão mais recente do cadastro deve ser mantida.
    """

    def test_happy_path_mantem_registros_mais_recentes(self):

        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        registros = {
            linha["cod_cliente"]: linha
            for linha in resultado.collect()
        }

        self.assertEqual(
            resultado.count(),
            3,
        )

        self.assertEqual(
            registros[1]["nm_cliente"],
            "CLIENTE MAIS RECENTE",
        )

        self.assertEqual(
            registros[3]["nm_cliente"],
            "SEGUNDA VERSAO",
        )



    """
    Caso de borda: cliente com apenas uma versão deve ser preservado.
    """

    def test_caso_borda_cliente_com_um_registro(self):

        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        cliente_unico = (
            resultado
            .filter(F.col("cod_cliente") == 2)
            .collect()
        )

        self.assertEqual(
            len(cliente_unico),
            1,
        )

        self.assertEqual(
            cliente_unico[0]["nm_cliente"],
            "CLIENTE UNICO",
        )



    """
    Caso extremo: após a deduplicação, o cod_cliente pode aparecer + 1x.
    """

    def test_resultado_sem_clientes_duplicados(self):

        dataframe = self.carregar_base_teste()

        resultado = deduplicar_clientes(dataframe)

        total_registros = resultado.count()

        total_clientes_distintos = (
            resultado
            .select("cod_cliente")
            .distinct()
            .count()
        )

        self.assertEqual(
            total_registros,
            total_clientes_distintos,
        )



    """
    Situação de erro: ausência da coluna dt_atualizacao deve causar erro.
    """

    def test_erro_sem_coluna_dt_atualizacao(self):

        dataframe = self.spark.createDataFrame(
            [
                (1, "CLIENTE SEM DATA"),
            ],
            [
                "cod_cliente",
                "nm_cliente",
            ],
        )

        with self.assertRaises(AnalysisException):
            deduplicar_clientes(dataframe).collect()


if __name__ == "__main__":
    unittest.main(
        argv=[""],
        exit=False,
        verbosity=2,
    )
# Out:
# Overwriting 5.TesteUnitario/unit_test.py

# %% [markdown]
# ### 6. Infra as Code
# #### Descrição
# - Desenvolva um script Terraform que crie um Glue Job. Abaixo alguns parametros que o serviço deve ter.
# - Parametros
#   - Script : script desenvolvido na etapa 2
#   - Versão: 5
#   - Workers: 10
#   - Tipo de Máquina: G1x
#   - Tag:
#      - Nome: projeto
#      - Valor: teste_eng_dados

# %%
# %%writefile 6.InfraAsCode/script.tf
#
# # ============================================================
# # Provider AWS
# # ============================================================
#
# terraform {
#   required_version = ">= 1.5.0"
#
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 6.0"
#     }
#   }
# }
#
# provider "aws" {
#   region = var.aws_region
# }
#
#
# # ============================================================
# # Variáveis
# # ============================================================
#
# variable "aws_region" {
#   description = "Região AWS onde os recursos serão criados."
#   type        = string
#   default     = "sa-east-1"
# }
#
# variable "glue_job_name" {
#   description = "Nome do AWS Glue Job."
#   type        = string
#   default     = "teste-eng-dados-etl-clientes"
# }
#
# variable "glue_role_arn" {
#   description = "ARN da IAM Role utilizada pelo AWS Glue Job."
#   type        = string
# }
#
# variable "script_s3_path" {
#   description = "Caminho no S3 onde está armazenado o script PySpark."
#   type        = string
#   default     = "s3://bucket-scripts/teste_eng_dados/1.ETL/script.py"
# }
#
#
# # ============================================================
# # AWS Glue Job
# # ============================================================
#
# resource "aws_glue_job" "etl_clientes" {
#   name     = var.glue_job_name
#   role_arn = var.glue_role_arn
#
#   command {
#     name            = "glueetl"
#     script_location = var.script_s3_path
#     python_version  = "3"
#   }
#
#   glue_version      = "5.0"
#   worker_type       = "G.1X"
#   number_of_workers = 10
#
#   max_retries = 1
#   timeout     = 60
#
#   default_arguments = {
#     "--job-language"                     = "python"
#     "--enable-metrics"                   = "true"
#     "--enable-continuous-cloudwatch-log" = "true"
#     "--enable-glue-datacatalog"          = "true"
#
#     "--source-path"    = "s3://bucket-origem/clientes_sinteticos.csv"
#     "--glue-database"  = "db_clientes"
#     "--bronze-table"   = "tabela_cliente_landing"
#     "--silver-table"   = "tb_cliente"
#   }
#
#   tags = {
#     projeto = "teste_eng_dados"
#   }
# }
#
#
# # ============================================================
# # Saídas
# # ============================================================
#
# output "glue_job_name" {
#   description = "Nome do Glue Job criado."
#   value       = aws_glue_job.etl_clientes.name
# }
#
# output "glue_job_arn" {
#   description = "ARN do Glue Job criado."
#   value       = aws_glue_job.etl_clientes.arn
# }
# Out:
# Overwriting 6.InfraAsCode/script.tf

# %%
# !wget -q https://releases.hashicorp.com/terraform/1.9.8/terraform_1.9.8_linux_amd64.zip
# !unzip -o terraform_1.9.8_linux_amd64.zip
# !mv terraform /usr/local/bin/
# !terraform version
# Out:
# Archive:  terraform_1.9.8_linux_amd64.zip
#   inflating: LICENSE.txt
#   inflating: terraform
# Terraform v1.9.8
# on linux_amd64
#
# Your version of Terraform is out of date! The latest version
# is 1.15.8. You can update by downloading from https://www.terraform.io/downloads.html

# %%
# !terraform fmt 6.InfraAsCode/script.tf
# Out:
# 6.InfraAsCode/script.tf

# %%
# %cd 6.InfraAsCode
# Out:
# /content/teste_eng_dados/6.InfraAsCode

# %%
# !terraform init -backend=false
# !terraform validate
# Out:
# Initializing provider plugins...
# - Finding hashicorp/aws versions matching "~> 6.0"...
# - Installing hashicorp/aws v6.54.0...
# - Installed hashicorp/aws v6.54.0 (signed by HashiCorp)
# Terraform has created a lock file .terraform.lock.hcl to record the provider
# selections it made above. Include this file in your version control repository
# so that Terraform can guarantee to make the same selections by default when
# you run "terraform init" in the future.
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.
# Success! The configuration is valid.

# %%
# !terraform version > 6.InfraAsCode/resultados.txt
# Out:
# /bin/bash: line 1: 6.InfraAsCode/resultados.txt: No such file or directory
